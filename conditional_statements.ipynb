# %% [markdown]
# #conditional statements in python
# python have 4 types of conditional statements
# 1. "IF" statement
# 2. "elif" statement
# 3. "else" statement
# 4. "nested" statement
#
# ``` python syntax - IF
# if ( condition ): #if condition is true then excecute or run statements inside if block statement
# statement2...
# ```
# ```python - if,else
# if( condition):
#     statement1
#     statement2...
# else:
#     statement1
#     statement2...
# ```
# ```python - if,elif,else
# if(condition):
# statements1..n
# elif(condition2):
# statements1..n
# elif(condition3):
# statement1..n
# else:
# statements1..n
# ```

# %%
#write a program to find the given number is odd?
number = int(input("please eneter number here:"))
if (number%2 ==1):
    print(number,"is odd number")
# Out:
# please eneter number here 3
# 3 is odd number

# %%
#write a prgram to find the given number is even or odd?
num= int(input("please eneter number here:"))
if (num%2 ==0):
    print(num,"is even number")
else:
    print(num,"is odd number")
# Out:
# please eneter number here: 7
# 7 is odd number

# %%
#write a program to find the given number is positive or negative or zero?
n = int(input("please enter a number here:"))
if (n>0):
    print(n,"is positive number")
elif (n<0):
    print(n,"is negative number")
else: 
    print(n,"is equal to 0")
# Out:
# please enter a number here: 0
# 0 is equal to 0

# %%
"""
write a program to find the grades based on marks
1. if marks is in between 80-100 - grade is A
2. if marks is in between 60-79 - grade is B
3. if marks is in between 40-59 - grade is C
4. if marks is in between 25-39 - grade is D
5. if marks is in between 0-24 - grade is fail
6. if marks other than abobe output is - please enter correct marks 

"""
marks= int(input("please enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"grade is A")
elif (marks>=60 and marks<=79):
    print(marks, "grade is B")
elif( marks>=40 and marks<=59):
    print(marks," grade is C")
elif( marks>=25 and marks<=39):
    print(marks," grade is D")
elif( marks>=0 and marks<=24):
    print(marks," grade is fail")
else:
    print("please enter correct marks")
# Out:
# please enter student marks here: 99
# 99 grade is A

# %%
#write a program to find the largest number from 3 numbers?
n1= int( input("please enter 1st number"))
n2= int( input("please enter 2nd number"))
n3= int( input("please enter 3rd number"))
if( n1>n2 and n1>n3):
        print(n1,"is the largest number")
elif( n2>n1 and n2>n3):
        print(n2,"is the largest number")
else:
    print(n3,"is the largest number")
# Out:
# please enter 1st number 69
# please enter 2nd number 42
# please enter 3rd number 57
# 69 is the largest number

# %%
#write a program to validate login credentials using conditional statements?
username=str(input("please enter username here:"))
if(username=="tia@123"):
    print("username is valid")
    password=str(input("please enter user password here:"))
    if (password=="TIA@12345"):
        print("user details are successfully validated, Thank you")
    else:
        print("password is wrong")
else:
    print("username is invalid")
# Out:
# please enter username here: tia@123
# username is valid
# please enter user password here: TIA@12345
# user details are successfully validated, Thank you

# %%
"""
write a program to find the even number with number of digits
1. if number is in between 1 to 9 then output is - 1 digit even number
2. if number is in between 10 to 99 then output is - 2 digit even number
3. if number is in between 100 to 999 then output is - 3 digit even number
4. if number is in between 1000 to 9999 then output is - 4 digit even number
5. if other than above range than output is weird even number

"""

n= int(input("please enter a number here:"))
if(n%2 ==0):
    if(n>=1 and n<=9):
         print(n, "is an 1 digit even number")
    elif (n>=10 and n<=99):
        print(n, "is an 2 digit even number")
    elif(n>=100 and n<=999):
        print(n, "is an 3 digit even number")
    elif(n>=1000 and n<=9999):
         print(n, "is an 4 digit even number")
    else:
        print("weird even number")
else:
    print("The number is an odd number")
# Out:
# please enter a number here: 8
# 8 is an 1 digit even number
