# %% [markdown]
# # variables in python
# 1. variable is memory allocation to a value
# 2. examples are name="hamsika"  age="16"

# %%
name=hamsika
age=16
salary=10000
print(name)
print(age)
print(salary)

# %%
hamsika
16
10000

# %%
# key points to define variables
1.variables does not start with digit
2.variables does not allowed special characters
3.do not use keywords as avariable
